# %%
import pandas as pd
import numpy as np

# %%
first_dataset = pd.read_csv("/content/deliveries.csv")
second_dataset = pd.read_csv("/content/matches.csv")

first_dataset.head()
# Out:
#    match_id  season  start_date                             venue  innings  \
# 0   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 1   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 2   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 3   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
# 4   1359475    2023  2023-03-31  Narendra Modi Stadium, Ahmedabad        1
#
#    ball         batting_team    bowling_team     striker non_striker  ...  \
# 0   0.1  Chennai Super Kings  Gujarat Titans   DP Conway  RD Gaikwad  ...
# 1   0.2  Chennai Super Kings  Gujarat Titans   DP Conway  RD Gaikwad  ...
# 2   0.3  Chennai Super Kings  Gujarat Titans  RD Gaikwad   DP Conway  ...
# 3   0.4  Chennai Super Kings  Gujarat Titans  RD Gaikwad   DP Conway  ...
# 4   0.5  Chennai Super Kings  Gujarat Titans   DP Conway  RD Gaikwad  ...
#
#   extras  wides  noballs  byes  legbyes  penalty  wicket_type  \
# ...

# %%
second_dataset.tail()
# Out:
#     season                        team1                 team2        date  \
# 69    2023  Royal Challengers Bangalore        Gujarat Titans  2023/05/21
# 70    2023          Chennai Super Kings        Gujarat Titans  2023/05/23
# 71    2023               Mumbai Indians  Lucknow Super Giants  2023/05/24
# 72    2023               Gujarat Titans        Mumbai Indians  2023/05/26
# 73    2023               Gujarat Titans   Chennai Super Kings  2023/05/29
#
#     match_number                   venue       city          toss_winner  \
# 69            70   M Chinnaswamy Stadium  Bengaluru       Gujarat Titans
# 70            71  MA Chidambaram Stadium    Chennai       Gujarat Titans
# 71            72  MA Chidambaram Stadium    Chennai       Mumbai Indians
# 72            73   Narendra Modi Stadium  Ahmedabad       Mumbai Indians
# 73            74   Narendra Modi Stadium  Ahmedabad  Chennai Super Kings
#
#    toss_decision player_of_match       umpire1      umpire2  \
# ...

# %%
first_dataset.columns
# Out:
# Index(['match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes',
#        'penalty', 'wicket_type', 'player_dismissed', 'other_wicket_type',
#        'other_player_dismissed'],
#       dtype='object')

# %%
first_dataset['total_run'] = first_dataset['runs_off_bat'] + first_dataset['extras']

# %%
first_dataset[['runs_off_bat', 'extras', 'total_run']]
# Out:
#        runs_off_bat  extras  total_run
# 0                 0       0          0
# 1                 0       1          1
# 2                 0       0          0
# 3                 1       0          1
# 4                 0       0          0
# ...             ...     ...        ...
# 17858             1       0          1
# 17859             1       0          1
# 17860             1       0          1
# 17861             6       0          6
# 17862             4       0          4
#
# [17863 rows x 3 columns]

# %%
first_dataset['match_number'] = first_dataset['match_id'].rank(method='dense').astype(int)

# %%
first_dataset['match_number'].nunique()
# Out:
# 74

# %%
total_runs = first_dataset.groupby(['match_id','innings', 'match_number']).sum()['total_run'].add(1).reset_index()
total_runs
# Out:
#      match_id  innings  match_number  total_run
# 0     1359475        1             1        179
# 1     1359475        2             1        183
# 2     1359476        1             2        192
# 3     1359476        2             2        147
# 4     1359477        1             3        194
# ..        ...      ...           ...        ...
# 142   1370351        2            72        102
# 143   1370352        1            73        234
# 144   1370352        2            73        172
# 145   1370353        1            74        215
# 146   1370353        2            74        172
#
# [147 rows x 4 columns]

# %%
match_df = second_dataset.merge(total_runs[['match_number','total_run']],left_on='match_number',right_on='match_number')
match_df
# Out:
#      season                 team1                  team2        date  \
# 0      2023   Chennai Super Kings         Gujarat Titans  2023/03/31
# 1      2023   Chennai Super Kings         Gujarat Titans  2023/03/31
# 2      2023          Punjab Kings  Kolkata Knight Riders  2023/04/01
# 3      2023          Punjab Kings  Kolkata Knight Riders  2023/04/01
# 4      2023  Lucknow Super Giants         Delhi Capitals  2023/04/01
# ..      ...                   ...                    ...         ...
# 142    2023        Mumbai Indians   Lucknow Super Giants  2023/05/24
# 143    2023        Gujarat Titans         Mumbai Indians  2023/05/26
# 144    2023        Gujarat Titans         Mumbai Indians  2023/05/26
# 145    2023        Gujarat Titans    Chennai Super Kings  2023/05/29
# 146    2023        Gujarat Titans    Chennai Super Kings  2023/05/29
#
#      match_number                                              venue  \
# ...

# %%
match_df['team1'].value_counts()
# Out:
# team1
# Chennai Super Kings            18
# Punjab Kings                   18
# Royal Challengers Bangalore    18
# Gujarat Titans                 16
# Rajasthan Royals               14
# Sunrisers Hyderabad            14
# Kolkata Knight Riders          14
# Lucknow Super Giants           13
# Mumbai Indians                 12
# Delhi Capitals                 10
# Name: count, dtype: int64

# %%
teams = ['Kolkata Knight Riders',
         'Chennai Super Kings',
         'Punjab Kings',
         'Rajasthan Royals',
         'Mumbai Indians',
         'Delhi Capitals',
         'Royal Challengers Bangalore',
         'Sunrisers Hyderabad',
         'Lucknow Super Giants',
         'Gujarat Titans'
         ]

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]
match_df['team1'].value_counts()
# Out:
# team1
# Chennai Super Kings            18
# Punjab Kings                   18
# Royal Challengers Bangalore    18
# Gujarat Titans                 16
# Rajasthan Royals               14
# Sunrisers Hyderabad            14
# Kolkata Knight Riders          14
# Lucknow Super Giants           13
# Mumbai Indians                 12
# Delhi Capitals                 10
# Name: count, dtype: int64

# %%
match_df.shape
# Out:
# (147, 19)

# %%
match_df.columns
# Out:
# Index(['season', 'team1', 'team2', 'date', 'match_number', 'venue', 'city',
#        'toss_winner', 'toss_decision', 'player_of_match', 'umpire1', 'umpire2',
#        'reserve_umpire', 'match_referee', 'winner', 'winner_runs',
#        'winner_wickets', 'match_type', 'total_run'],
#       dtype='object')

# %%
match_df = match_df[['match_number','city','winner','total_run', 'team1', 'team2']]
match_df.shape
# Out:
# (147, 6)

# %%
second_innings = match_df.merge(first_dataset,on='match_number')
second_innings
# Out:
#        match_number       city               winner  total_run_x  \
# 0                 1  Ahmedabad       Gujarat Titans          179
# 1                 1  Ahmedabad       Gujarat Titans          179
# 2                 1  Ahmedabad       Gujarat Titans          179
# 3                 1  Ahmedabad       Gujarat Titans          179
# 4                 1  Ahmedabad       Gujarat Titans          179
# ...             ...        ...                  ...          ...
# 35603            74  Ahmedabad  Chennai Super Kings          172
# 35604            74  Ahmedabad  Chennai Super Kings          172
# 35605            74  Ahmedabad  Chennai Super Kings          172
# 35606            74  Ahmedabad  Chennai Super Kings          172
# 35607            74  Ahmedabad  Chennai Super Kings          172
#
#                      team1                team2  match_id  season  start_date  \
# 0      Chennai Super Kings       Gujarat Titans   1359475    2023  2023-03-31
# ...

# %%
second_innings = second_innings[second_innings['innings']==2]
second_innings.shape
# Out:
# (17242, 29)

# %%
second_innings.columns
# Out:
# Index(['match_number', 'city', 'winner', 'total_run_x', 'team1', 'team2',
#        'match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes',
#        'penalty', 'wicket_type', 'player_dismissed', 'other_wicket_type',
#        'other_player_dismissed', 'total_run_y'],
#       dtype='object')

# %%
second_innings['bowling_team'].unique()
# Out:
# array(['Chennai Super Kings', 'Punjab Kings', 'Lucknow Super Giants',
#        'Rajasthan Royals', 'Mumbai Indians', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Sunrisers Hyderabad', 'Gujarat Titans',
#        'Royal Challengers Bangalore'], dtype=object)

# %%
second_innings['total_run_y'] = pd.to_numeric(second_innings['total_run_y'], errors='coerce')
second_innings['current_Score'] = second_innings.groupby(['match_id', 'innings'])['total_run_y'].cumsum()
second_innings['current_Score'] = second_innings.groupby(['match_id', 'innings'])['current_Score'].transform(lambda x: x.sub(x.iloc[0]))
second_innings
# Out:
# <ipython-input-24-cb2c76e96ec6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['total_run_y'] = pd.to_numeric(second_innings['total_run_y'], errors='coerce')
# <ipython-input-24-cb2c76e96ec6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['current_Score'] = second_innings.groupby(['match_id', 'innings'])['total_run_y'].cumsum()
# <ipython-input-24-cb2c76e96ec6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
second_innings.columns
# Out:
# Index(['match_number', 'city', 'winner', 'total_run_x', 'team1', 'team2',
#        'match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes',
#        'penalty', 'wicket_type', 'player_dismissed', 'other_wicket_type',
#        'other_player_dismissed', 'total_run_y', 'current_Score'],
#       dtype='object')

# %%
second_inning = second_innings[['match_number', 'city', 'winner', 'team1', 'team2',
       'match_id', 'innings', 'ball', 'player_dismissed',
       'batting_team', 'bowling_team', 'runs_off_bat', 'extras', 'total_run_y']]
second_inning
# Out:
#        match_number       city               winner                team1  \
# 121               1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 122               1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 123               1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 124               1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 125               1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# ...             ...        ...                  ...                  ...
# 35603            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 35604            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 35605            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 35606            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 35607            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
#
#                      team2  match_id  innings  ball player_dismissed  \
# ...

# %%
second_inning = second_inning.drop_duplicates(subset=['match_number', 'city', 'winner', 'team1', 'team2',
       'match_id', 'innings', 'ball', 'player_dismissed',
       'batting_team', 'bowling_team', 'runs_off_bat', 'extras', 'total_run_y'])

second_inning
# Out:
#        match_number       city               winner                team1  \
# 121               1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 122               1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 123               1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 124               1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 125               1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# ...             ...        ...                  ...                  ...
# 35387            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 35388            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 35389            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 35390            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 35391            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
#
#                      team2  match_id  innings  ball player_dismissed  \
# ...

# %%
# second_inning['current_Score'] = second_inning.groupby('match_number').cumsum()['total_run_y']
# second_inning
second_inning['total_run_y'] = pd.to_numeric(second_inning['total_run_y'], errors='coerce')
second_inning['current_Score'] = second_inning.groupby('match_number')['total_run_y'].cumsum()
second_inning
# Out:
# <ipython-input-28-3f163768d1b9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_inning['total_run_y'] = pd.to_numeric(second_inning['total_run_y'], errors='coerce')
# <ipython-input-28-3f163768d1b9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_inning['current_Score'] = second_inning.groupby('match_number')['total_run_y'].cumsum()
#        match_number       city               winner                team1  \
# ...

# %%
first_innings = match_df.merge(first_dataset,on='match_number')
first_innings
# Out:
#        match_number       city               winner  total_run_x  \
# 0                 1  Ahmedabad       Gujarat Titans          179
# 1                 1  Ahmedabad       Gujarat Titans          179
# 2                 1  Ahmedabad       Gujarat Titans          179
# 3                 1  Ahmedabad       Gujarat Titans          179
# 4                 1  Ahmedabad       Gujarat Titans          179
# ...             ...        ...                  ...          ...
# 35603            74  Ahmedabad  Chennai Super Kings          172
# 35604            74  Ahmedabad  Chennai Super Kings          172
# 35605            74  Ahmedabad  Chennai Super Kings          172
# 35606            74  Ahmedabad  Chennai Super Kings          172
# 35607            74  Ahmedabad  Chennai Super Kings          172
#
#                      team1                team2  match_id  season  start_date  \
# 0      Chennai Super Kings       Gujarat Titans   1359475    2023  2023-03-31
# ...

# %%
first_innings = first_innings[first_innings['innings']==1]
first_innings.shape
# Out:
# (18366, 29)

# %%
first_innings = first_innings.drop_duplicates(subset=['match_number', 'city', 'winner', 'team1', 'team2', 'match_id', 'innings', 'ball', 'batting_team', 'bowling_team', 'runs_off_bat', 'extras', 'total_run_y'])

# %%
# Group by 'match_number' and find the maximum 'total_run_x' for each match number
max_total_run_x_per_match = first_innings.groupby('match_number')['total_run_x'].max()

# Convert the result to a list
result_list = max_total_run_x_per_match.reset_index().values.tolist()
result_list
# Out:
# [[1, 179],
#  [2, 192],
#  [3, 194],
#  [4, 204],
#  [5, 172],
#  [6, 218],
#  [7, 163],
#  [8, 198],
#  [9, 205],
#  [10, 122],
#  [11, 200],
#  [12, 158],
#  [13, 205],
#  [14, 144],
#  [15, 213],
#  [16, 173],
#  [17, 176],
#  [18, 154],
#  [19, 229],
#  [20, 175],
#  [21, 160],
#  [22, 186],
#  [23, 178],
#  [24, 227],
#  [25, 193],
#  [26, 155],
#  [27, 175],
#  [28, 128],
#  [29, 135],
#  [30, 136],
#  [31, 215],
#  [32, 190],
#  [33, 236],
#  [34, 145],
#  [35, 208],
#  [36, 201],
#  [37, 203],
#  [38, 258],
#  [39, 180],
#  [40, 198],
#  [41, 201],
#  [42, 213],
#  [43, 127],
#  [44, 131],
#  [45, 126],
#  [46, 215],
#  [47, 172],
#  [48, 119],
#  [49, 140],
#  [50, 182],
#  [51, 228],
#  [52, 215],
#  [53, 180],
#  [54, 200],
#  [55, 168],
#  [56, 150],
#  [57, 219],
#  [58, 183],
#  [59, 168],
#  [60, 172],
#  [61, 145],
#  [62, 189],
#  [63, 178],
#  [64, 214],
#  [65, 187],
#  [66, 188],
#  [67, 224],
#  [68, 177],
#  [69, 201],
#  [70, 198],
#  [71, 173],
#  [72, 183],
# ...

# %%
# Convert the result list to a DataFrame with columns 'match_number' and 'max_total_run_x'
target_df = pd.DataFrame(result_list, columns=['match_number', 'max_total_run_x'])

# Merge 'second_inning' with the target DataFrame based on 'match_number'
second_inning = pd.merge(second_inning, target_df, on='match_number', how='left')
second_inning
# Out:
#       match_number       city               winner                team1  \
# 0                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 1                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 2                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 3                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 4                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# ...            ...        ...                  ...                  ...
# 8616            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8617            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8618            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8619            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8620            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
#
#                     team2  match_id  innings  ball player_dismissed  \
# ...

# %%
# Convert the 'ball' column to string and split it into two columns
second_inning[['over', 'balls']] = second_inning['ball'].astype(str).str.split('.', expand=True)

# Convert 'over' and 'balls' columns to integers
second_inning['over'] = second_inning['over'].astype(int)
second_inning['balls'] = second_inning['balls'].astype(int)
second_inning = second_inning.drop(['ball'], axis=1)
second_inning
# Out:
#       match_number       city               winner                team1  \
# 0                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 1                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 2                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 3                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 4                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# ...            ...        ...                  ...                  ...
# 8616            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8617            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8618            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8619            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8620            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
#
#                     team2  match_id  innings player_dismissed  \
# ...

# %%
# second_inning['current_Score'] = second_inning.groupby('match_number').cumsum()['total_run_y']
# second_inning
second_inning['total_run_y'] = pd.to_numeric(second_inning['total_run_y'], errors='coerce')
second_inning['current_Score'] = second_inning.groupby('match_number')['total_run_y'].cumsum()
second_inning
# Out:
#       match_number       city               winner                team1  \
# 0                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 1                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 2                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 3                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 4                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# ...            ...        ...                  ...                  ...
# 8616            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8617            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8618            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8619            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8620            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
#
#                     team2  match_id  innings player_dismissed  \
# ...

# %%
# second_inning['current_Score'] = second_inning.groupby('match_number').cumsum()['total_run_y']
# second_inning
# Convert 'total_run_y' to numeric before applying cumsum
second_inning['total_run_y'] = pd.to_numeric(second_inning['total_run_y'], errors='coerce')

# Calculate current_Score as the cumulative sum of total_run_y within each match number
second_inning['current_Score'] = second_inning.groupby('match_number')['total_run_y'].cumsum()
second_inning
# Out:
#       match_number       city               winner                team1  \
# 0                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 1                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 2                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 3                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 4                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# ...            ...        ...                  ...                  ...
# 8616            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8617            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8618            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8619            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8620            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
#
#                     team2  match_id  innings player_dismissed  \
# ...

# %%
second_inning['runs_left'] = second_inning['max_total_run_x'] - second_inning['current_Score']
second_inning
# Out:
#       match_number       city               winner                team1  \
# 0                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 1                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 2                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 3                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 4                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# ...            ...        ...                  ...                  ...
# 8616            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8617            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8618            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8619            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8620            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
#
#                     team2  match_id  innings player_dismissed  \
# ...

# %%
second_inning['balls_left'] = 126 - (second_inning['over']*6 +second_inning['balls'])
second_inning
# Out:
#       match_number       city               winner                team1  \
# 0                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 1                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 2                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 3                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 4                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# ...            ...        ...                  ...                  ...
# 8616            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8617            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8618            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8619            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8620            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
#
#                     team2  match_id  innings player_dismissed  \
# ...

# %%
second_inning.columns
# Out:
# Index(['match_number', 'city', 'winner', 'team1', 'team2', 'match_id',
#        'innings', 'player_dismissed', 'batting_team', 'bowling_team',
#        'runs_off_bat', 'extras', 'total_run_y', 'current_Score',
#        'max_total_run_x', 'over', 'balls', 'runs_left', 'balls_left'],
#       dtype='object')

# %%
# Select the columns of interest
columns_to_check = ['current_Score', 'runs_left', 'balls_left']

# Check how many values in each column are negative
negative_counts = second_inning[columns_to_check].lt(0).sum()

# Display the counts
print("Number of negative values in each column:")
print(negative_counts)
# Out:
# Number of negative values in each column:
# current_Score     0
# runs_left        17
# balls_left        0
# dtype: int64

# %%
# Fill NaN values in 'player_dismissed' with "0"
second_inning['player_dismissed'] = second_inning['player_dismissed'].fillna("0")

# Convert "player_dismissed" to binary values: "1" for dismissal, "0" otherwise
second_inning['player_dismissed'] = second_inning['player_dismissed'].apply(lambda x: "1" if x != "0" else "0")

# Convert column to integer type after handling unwanted characters
second_inning['player_dismissed'] = second_inning['player_dismissed'].replace({" ": "0"}).astype(int)

# Compute cumulative wickets per match
second_inning['wickets'] = second_inning.groupby('match_number')['player_dismissed'].cumsum()

# Compute remaining wickets
second_inning['wickets_remaining'] = 10 - second_inning['wickets']

# Display the first few rows to verify output
second_inning
# Out:
#       match_number       city               winner                team1  \
# 0                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 1                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 2                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 3                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 4                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# ...            ...        ...                  ...                  ...
# 8616            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8617            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8618            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8619            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8620            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
#
#                     team2  match_id  innings  player_dismissed  \
# ...

# %%
second_inning['crr'] = round((second_inning['current_Score']*6)/(120 - second_inning['balls_left']),2)
second_inning['rrr'] = round((second_inning['runs_left']*6)/(second_inning['balls_left']),2)
second_inning
# Out:
#       match_number       city               winner                team1  \
# 0                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 1                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 2                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 3                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# 4                1  Ahmedabad       Gujarat Titans  Chennai Super Kings
# ...            ...        ...                  ...                  ...
# 8616            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8617            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8618            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8619            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
# 8620            74  Ahmedabad  Chennai Super Kings       Gujarat Titans
#
#                     team2  match_id  innings  player_dismissed  \
# ...

# %%
def winner(team):
    return 1 if team['batting_team'] == team['winner'] else 0
second_inning['results'] = second_inning.apply(winner,axis=1)
second_inning.head()
# Out:
#    match_number       city          winner                team1  \
# 0             1  Ahmedabad  Gujarat Titans  Chennai Super Kings
# 1             1  Ahmedabad  Gujarat Titans  Chennai Super Kings
# 2             1  Ahmedabad  Gujarat Titans  Chennai Super Kings
# 3             1  Ahmedabad  Gujarat Titans  Chennai Super Kings
# 4             1  Ahmedabad  Gujarat Titans  Chennai Super Kings
#
#             team2  match_id  innings  player_dismissed    batting_team  \
# 0  Gujarat Titans   1359475        2                 0  Gujarat Titans
# 1  Gujarat Titans   1359475        2                 0  Gujarat Titans
# 2  Gujarat Titans   1359475        2                 0  Gujarat Titans
# 3  Gujarat Titans   1359475        2                 0  Gujarat Titans
# 4  Gujarat Titans   1359475        2                 0  Gujarat Titans
#
#           bowling_team  ...  max_total_run_x  over  balls  runs_left  \
# 0  Chennai Super Kings  ...              179     0      1        179
# ...

# %%
required_data = second_inning[['batting_team','bowling_team','city','runs_left','balls_left','wickets_remaining','max_total_run_x','crr','rrr','results']]
required_data
# Out:
#              batting_team         bowling_team       city  runs_left  \
# 0          Gujarat Titans  Chennai Super Kings  Ahmedabad        179
# 1          Gujarat Titans  Chennai Super Kings  Ahmedabad        179
# 2          Gujarat Titans  Chennai Super Kings  Ahmedabad        179
# 3          Gujarat Titans  Chennai Super Kings  Ahmedabad        178
# 4          Gujarat Titans  Chennai Super Kings  Ahmedabad        176
# ...                   ...                  ...        ...        ...
# 8616  Chennai Super Kings       Gujarat Titans  Ahmedabad         56
# 8617  Chennai Super Kings       Gujarat Titans  Ahmedabad         55
# 8618  Chennai Super Kings       Gujarat Titans  Ahmedabad         54
# 8619  Chennai Super Kings       Gujarat Titans  Ahmedabad         48
# 8620  Chennai Super Kings       Gujarat Titans  Ahmedabad         44
#
#       balls_left  wickets_remaining  max_total_run_x    crr   rrr  results
# ...

# %%
required_data = required_data.replace([np.inf, -np.inf], np.nan)
required_data = required_data.dropna()
required_data = required_data[required_data['crr'] >= 0]
columns_to_check = ['runs_left', 'balls_left', 'wickets_remaining', 'max_total_run_x', 'crr', 'rrr', 'results']

required_data = required_data[~(required_data[columns_to_check] < 0).any(axis=1)]
numeric = required_data[['runs_left', 'balls_left', 'wickets_remaining', 'max_total_run_x', 'crr', 'rrr', 'results']]
has_infinite_values = np.any(np.isinf(numeric))

# Check for negative values in the entire DataFrame
has_negative_values = (numeric < 0).any().any()

# Check for null values in the entire DataFrame
has_null_values = numeric.isnull().any().any()

# Display the results
print(f"Has Infinite Values: {has_infinite_values}")
print(f"Has Negative Values: {has_negative_values}")
print(f"Has Null Values: {has_null_values}")
# Out:
# Has Infinite Values: False
# Has Negative Values: False
# Has Null Values: False

# %%
required_data.to_csv("csv2023.csv", index=False)
required_data.head(2)
# Out:
#      batting_team         bowling_team       city  runs_left  balls_left  \
# 0  Gujarat Titans  Chennai Super Kings  Ahmedabad        179         125
# 1  Gujarat Titans  Chennai Super Kings  Ahmedabad        179         124
#
#    wickets_remaining  max_total_run_x  crr   rrr  results
# 0                 10              179 -0.0  8.59        1
# 1                 10              179 -0.0  8.66        1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
